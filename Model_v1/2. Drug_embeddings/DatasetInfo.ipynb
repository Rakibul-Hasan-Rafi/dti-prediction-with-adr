# %%
import pandas as pd

# %%
EGNN_pd = pd.read_parquet("EGNN_drug_embeddings_v2.parquet")
Chemberta_pd = pd.read_parquet("smiles_embeddings_chemberta.parquet")
smiles2vec_pd = pd.read_parquet("smiles_embeddings_smiles2vec.parquet")

# %%
print("EGNN Dataset Info:")
print(EGNN_pd.info())
print("\n")
print("Chemberta Dataset Info:")
print(Chemberta_pd.info())
print("\n")
print("Smiles2Vec Dataset Info:")
print(smiles2vec_pd.info())
# Out:
# EGNN Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   drug_chembl_id  1028 non-null   object
#  1   rxcui           1028 non-null   object
#  2   embedding       1028 non-null   object
# dtypes: object(3)
# memory usage: 24.2+ KB
# None
#
#
# Chemberta Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   drug_chembl_id  1028 non-null   object
#  1   smiles          1028 non-null   object
#  2   embedding       1028 non-null   object
#  3   embedding_dim   1028 non-null   int64
#  4   model_name      1028 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 40.3+ KB
# None
#
#
# Smiles2Vec Dataset Info:
# ...

# %%
EGNN_pd.head(2)
# Out:
#   drug_chembl_id   rxcui                                          embedding
# 0     CHEMBL1000   20610  [0.02189382165670395, 0.016782937571406364, -0...
# 1     CHEMBL1002  237159  [0.02701766975224018, 0.033309683203697205, -0...

# %%
Chemberta_pd.head(2)
# Out:
#   drug_chembl_id                                       smiles  \
# 0     CHEMBL1000  O=C(O)COCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
# 1     CHEMBL1002            CC(C)(C)NC[C@H](O)c1ccc(O)c(CO)c1
#
#                                            embedding  embedding_dim  \
# 0  [0.008678080514073372, -0.08597195148468018, -...            384
# 1  [0.0806661993265152, -0.13387498259544373, 0.0...            384
#
#                    model_name
# 0  DeepChem/ChemBERTa-77M-MLM
# 1  DeepChem/ChemBERTa-77M-MLM

# %%
smiles2vec_pd.head(2)
# Out:
#   drug_chembl_id                                       smiles  \
# 0     CHEMBL1000  O=C(O)COCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
# 1     CHEMBL1002            CC(C)(C)NC[C@H](O)c1ccc(O)c(CO)c1
#
#                                            embedding  embedding_dim
# 0  [-1.063607931137085, -0.598328173160553, 0.926...            256
# 1  [-1.0096789598464966, -0.6098981499671936, 0.9...            256
